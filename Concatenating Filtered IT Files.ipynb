# %%
import os
import pandas as pd
from datetime import datetime

# %%
path="Filltered_Files"

# %%
dir_list = os.listdir(path)
dir_list
# Out:
# ['k-Android-ios-Mobile-Flutter-Xamarin-React Native-Swift-Kotlin-Ionic_26_sep_to_26_nov_229_jobs_102_titles_v5_Feature_Eng_Processed.csv',
#  'k-App_26_sep_to_26_nov_143_jobs_98_titles_v5_Feature_Eng_Processed.csv',
#  'k-Back_26_sep_to_26_nov_230_jobs_81_titles_v5_Feature_Eng_Processed.csv',
#  'k-C++-C#-dotnet-.net_26_sep_to_26_nov_189_jobs_99_titles_v5_Feature_Eng_Processed.csv',
#  'k-Cloud-AWS-Azure-GCP-IBM-Salesforce-Oracle_26_sep_to_26_nov_195_jobs_138_titles_v5_Feature_Eng_Processed.csv',
#  'k-data-analyst-Analytics-Analysis-Artificial_intelligence-business_intelligence-Machine_Learning-Deep_Learning-Computer_vision-NLP-SQL-Power_BI-Tableau_26_sep_to_26_nov_771_jobs_464_titles_v5_Feature_Eng_Processed.csv',
#  'k-Desktop_26_sep_to_26_nov_10_jobs_6_titles_v5_Feature_Eng_Processed.csv',
#  'k-Devops_26_sep_to_26_nov_80_jobs_31_titles_v5_Feature_Eng_Processed.csv',
#  'k-Front_26_sep_to_26_nov_114_jobs_66_titles_v5_Feature_Eng_Processed.csv',
# ...

# %%
len(dir_list)
# Out:
# 27

# %%
# dates=[file.split('_')[3] for file in dir_list]
# dates.sort(key=lambda date: datetime.strptime(date, "%d-%b-%Y"))
# file_names=[]
# for date in dates:
#     for file in dir_list:
#         if file.split('_')[3]==date:
#             file_names.append(file)
# file_names
# Out:
# ['Linkedin_Job_Details_24-Oct-2023_338-jobs_14-pages.csv',
#  'Linkedin_Job_Details_25-Oct-2023_384-jobs_16-pages.csv',
#  'Linkedin_Job_Details_26-Oct-2023_304-jobs_13-pages.csv',
#  'Linkedin_Job_Details_27-Oct-2023_306-jobs_14-pages.csv',
#  'Linkedin_Job_Details_28-Oct-2023_369-jobs_16-pages.csv',
#  'Linkedin_Job_Details_29-Oct-2023_144-jobs_6-pages.csv',
#  'Linkedin_Job_Details_30-Oct-2023_100-jobs_4-pages.csv']

# %%
df_concat=None
for file in dir_list:
    df=pd.read_csv(path+'/'+file)
    df_concat=pd.concat([df_concat,df],ignore_index=True)

# %%
df_concat
# Out:
#                                               Job Title  \
# 0                                            iOS Intern
# 1                                 Trainee iOS Developer
# 2                                     Android Developer
# 3                       MERN and React Native Developer
# 4                          Mobile Application Developer
# ...                                                 ...
# 4685  Lead Software Engineer, Trilogy (Remote) - $10...
# 4686  Senior C++ Software Engineer, GFI Software (Re...
# 4687                                        QA Engineer
# 4688  Principal Software Engineer, IgniteTech (Remot...
# 4689    Software Development Support Engineer (L2 & L3)
#
#                                                Job Info  \
# 0     AusSource Enterprises (SMC-PRIVATE) LIMITED · ...
# 1     TechSwivel (Private) Limited · Lahore, Punjab,...
# 2     MWAN Mobile · Islāmābād, Pakistan (On-site)  \...
# 3     TecStik · Karāchi, Sindh, Pakistan (On-site)  ...
# ...

# %%
len(df_concat)
# Out:
# 4690

# %%
n_titles=len(df_concat['Job Title'].unique())
n_titles
# Out:
# 1856

# %%
folder_path='Filltered_Files-concatenated/'
folder_path
# Out:
# 'Filltered_Files-concatenated/'

# %%
df_concat.to_csv(folder_path+f'IT_roles_Linkedin_Job_Details_and_Job_Descriptions_26-sep-to-26-nov_{len(df_concat)}-jobs-{n_titles}_titles_v5_Feature_Eng_Processed.csv',index=False)
