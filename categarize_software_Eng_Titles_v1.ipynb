# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Filltered_Files/software_engineer_26_sep_to_26_nov_735_jobs_304_titles_v5_Feature_Eng_Processed.csv')
df
# Out:
#                                              Job Title  \
# 0                                    Software Engineer
# 1                Software Engineer - Product Operation
# 2                                   SOFTWARE DEVELOPER
# 3                                    Software Engineer
# 4                  Software Quality Assurance Engineer
# ..                                                 ...
# 728  Lead Software Engineer, Trilogy (Remote) - $10...
# 729  Senior C++ Software Engineer, GFI Software (Re...
# 730                                        QA Engineer
# 731  Principal Software Engineer, IgniteTech (Remot...
# 732    Software Development Support Engineer (L2 & L3)
#
#                                               Job Info  \
# 0    Jin Technologies Private Limited · Islamabad, ...
# 1    i2c Inc. · Lahore, Punjab, Pakistan (On-site) ...
# 2    360 TECHNOLOGIES · Islamabad, Islāmābād, Pakis...
# 3    Telenor · Islamabad, Islāmābād, Pakistan (On-s...
# ...

# %%
df.isnull().sum()
# Out:
# Job Title               0
# Job Info                0
# Job Type                0
# Job Link_x              0
# employees               0
# Job ID                  0
# Job Link_y              0
# Job Desception          2
# Company Info          151
# company                 0
# location_1              0
# location_2              0
# Remote/Onsite           0
# n_applicant           274
# job posting time        0
# Job Type nElements      0
# Job-Type                0
# Experience Level        0
# Comp_N_Employees        0
# Comp_Industry           0
# dtype: int64

# %%
df['Job Title'].unique()
# Out:
# array(['Software Engineer', 'Software Engineer - Product Operation',
#        'SOFTWARE DEVELOPER', 'Software Quality Assurance Engineer',
#        'Senior Software Engineer', 'Software Engineer-Integration',
#        'AI-Augmented Software Developer, Trilogy (Remote) - $200,000/year USD',
#        'Senior Software Quality Assurance Engineer',
#        'Software Development Engineer in Test (SDET)',
#        'Software Developer', 'Software Engineer - Marketing Platform',
#        'Senior QA Engineer',
#        'Senior Software Development Project Manager',
#        'Software Quality Assurance Analyst',
#        'Software Architect Lead Developer',
#        'Software Engineer (.Net/MVC)', 'Principal Software Engineer',
#        'Senior Software Engineer (.NET/ React Js)',
#        'Principal Software Engineer Full Stack PHP',
#        'Senior Java Software Engineer',
#        'Team Lead IT Software Development (m/f/d)',
# ...

# %%
len(df['Job Title'].unique())
# Out:
# 304

# %%
df['Job Title'].value_counts()[:40]
# Out:
# Job Title
# Software Engineer                                                                             56
# Senior Software Engineer                                                                      45
# Lead Software Engineer, Trilogy (Remote) - $100,000/year USD                                  26
# Senior Software Engineer, Trilogy (Remote) - $100,000/year USD                                25
# Software Engineering Manager, Trilogy (Remote) - $100,000/year USD                            15
# Software Development Engineer, Trilogy (Remote) - $100,000/year USD                           11
# Senior Software Architect, Trilogy (Remote) - $100,000/year USD                               11
# Software Developer                                                                            11
# Senior Software Engineering Manager, Trilogy (Remote) - $100,000/year USD                     10
# ...

# %%
df['Job Title_2'] = None

# %% [markdown]
# ## Specilized titles

# %% [raw]
# specilized_titles=['Software Engineer','Embeded Software Engineer','AI-Augmented Engineer','Systekm Software Engineer','Cybersecurity Engineer']

# %% [raw]
# nano roles vs big role
# cover frameworks first

# %%
it_tech_pattern = 'PHP'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                              Job Title  \
# 29          Principal Software Engineer Full Stack PHP
# 312                     Senior Software Engineer (PHP)
# 334         WordPress/PHP (Back-end) Software Engineer
# 398                     Senior Software Engineer (PHP)
# 426                     Senior Software Engineer (PHP)
# 447  Senior Software Engineer - WordPress & PHP Pro...
# 475                       Senior Software Engineer PHP
# 476                     Senior Software Engineer (PHP)
# 495                     Senior Software Engineer (PHP)
# 515             Senior Software Engineer (GoLang, PHP)
# 539             Senior Software Engineer (GoLang, PHP)
# 550                Software Developer (Laravel/PHP/JS)
# 557             Senior Software Engineer (PHP, GoLang)
# 571                            Software Engineer (PHP)
# 586             Senior Software Engineer (PHP, GoLang)
# 630             Senior Software Engineer (PHP, GoLang)
# ...

# %% [markdown]
# ### Front-End devoloper

# %%
df[df['Job Title']=='Software Engineer (Front End)']['Job Desception'].iloc[0]
# Out:
# 'About the job\n            \n\n \nDescriptionWe are looking for a Software Engineer, experienced in React and other frontend programming languages and is interested in being part of a platform that handles millions of requests per day. You will be conceiving, designing and delivering the most complex products and pushing the boundaries of perfection. Continuous integrations, auto-scaled rolling releases, creating event-driven service-oriented architectures are all part of the daily gig.At dubizzle you\'d be part of high performing cross-functional "Squads" set with a mission to provide win-win exchanges for our beloved users.In This Role You Will Work closely with other teams from the early stages of design all the way through identifying and resolving production issues, and handling the complete SDLC.Support a wide range of products focusing on automation, availability and performance, and above all reliability as well as supporting mobile engineers and business intelligence leadin
# ...

# %%
it_tech_pattern = 'Front End|Front-End'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                    Job Title  \
# 84               Front-End Software Engineer
# 291            Software Engineer (Front End)
# 313            Software Engineer - Front End
# 331  Principal Software Engineer - Front End
#
#                                               Job Info  \
# 84   Turing · Pakistan (Remote) Reposted  \n1 week ...
# 291  Bayut.com · Karāchi, Sindh, Pakistan Reposted ...
# 313  i2c Inc. · Lahore, Punjab, Pakistan  \n5 days ...
# 331  i2c Inc. · Lahore, Punjab, Pakistan  \n5 days ...
#
#                                            Job Type  \
# 84                          Full-time · Entry level
# 291                     Full-time\n\n \nEntry level
# 313       On-site\n\n \nFull-time\n\n \nEntry level
# 331  On-site\n\n \nFull-time\n\n \nMid-Senior level
#
#                                         Job Link_x  \
# 84   https://www.linkedin.com/jobs/view/3728826214
# 291  https://www.linkedin.com/jobs/view/3451370782
# ...

# %%
# conndition=df['Job Title'].str.contains(it_tech_pattern, case=False)
# df.loc[conndition, 'Job Title_2'] = 'Front-End Developer'

# %%
# df[df['Job Title_2']=='Front-End Developer']['Job Title_2']

# %% [markdown]
#  Back-End Devoloper

# %% [markdown]
# ### Software Engineer

# %%
# it_tech_pattern = 'Software Engineer|Software Developer|Software Architect|Software/Application Developer|Software Development Engineer|Software project|Software Delivery|software support|Software team|Software Solutions|Software Excellence|Software Development|Pre-Sales Software|Software Document'
# filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
# filtered_df

# %%
it_tech_pattern = 'Software'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                              Job Title  \
# 0                                    Software Engineer
# 1                Software Engineer - Product Operation
# 2                                   SOFTWARE DEVELOPER
# 3                                    Software Engineer
# 4                  Software Quality Assurance Engineer
# ..                                                 ...
# 727                                 Pre-Sales Software
# 728  Lead Software Engineer, Trilogy (Remote) - $10...
# 729  Senior C++ Software Engineer, GFI Software (Re...
# 731  Principal Software Engineer, IgniteTech (Remot...
# 732    Software Development Support Engineer (L2 & L3)
#
#                                               Job Info  \
# 0    Jin Technologies Private Limited · Islamabad, ...
# 1    i2c Inc. · Lahore, Punjab, Pakistan (On-site) ...
# 2    360 TECHNOLOGIES · Islamabad, Islāmābād, Pakis...
# 3    Telenor · Islamabad, Islāmābād, Pakistan (On-s...
# ...

# %%
# filtered_df['Job Title'].unique()

# %%
conndition=df['Job Title'].str.contains(it_tech_pattern, case=False)
df.loc[conndition, 'Job Title_2'] = 'Software Engineer'

# %%
df[df['Job Title_2']=='Software Engineer']['Job Title_2']
# Out:
# 0      Software Engineer
# 1      Software Engineer
# 2      Software Engineer
# 3      Software Engineer
# 4      Software Engineer
#              ...
# 727    Software Engineer
# 728    Software Engineer
# 729    Software Engineer
# 731    Software Engineer
# 732    Software Engineer
# Name: Job Title_2, Length: 687, dtype: object

# %%
it_tech_pattern = 'Software Quality assurance|SQA|QA engineer|testing|Automation|SDET|Software Development Engineer in Test|Software Tester|QA'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                            Job Title  \
# 4                Software Quality Assurance Engineer
# 8                Software Quality Assurance Engineer
# 11               Software Quality Assurance Engineer
# 14        Senior Software Quality Assurance Engineer
# 15      Software Development Engineer in Test (SDET)
# ..                                               ...
# 652  Program Officer - SBCC - Qadam Ba Qadam Project
# 682          Jr. Software Quality Assurance Engineer
# 712                            Software Engineer SQA
# 724                                      SQA Analyst
# 730                                      QA Engineer
#
#                                               Job Info  \
# 4    Brickclay · Faisalabad, Punjab, Pakistan (On-s...
# 8    STARZPLAY · Lahore, Punjab, Pakistan (On-site)...
# 11   RLTSquare · Lahore, Punjab, Pakistan (On-site)...
# 14   Datics AI · Lahore District, Punjab, Pakistan ...
# ...

# %%
it_tech_pattern = 'Quality|SQA|QA|test|Automation|SDET'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                            Job Title  \
# 4                Software Quality Assurance Engineer
# 8                Software Quality Assurance Engineer
# 11               Software Quality Assurance Engineer
# 14        Senior Software Quality Assurance Engineer
# 15      Software Development Engineer in Test (SDET)
# ..                                               ...
# 652  Program Officer - SBCC - Qadam Ba Qadam Project
# 682          Jr. Software Quality Assurance Engineer
# 712                            Software Engineer SQA
# 724                                      SQA Analyst
# 730                                      QA Engineer
#
#                                               Job Info  \
# 4    Brickclay · Faisalabad, Punjab, Pakistan (On-s...
# 8    STARZPLAY · Lahore, Punjab, Pakistan (On-site)...
# 11   RLTSquare · Lahore, Punjab, Pakistan (On-site)...
# 14   Datics AI · Lahore District, Punjab, Pakistan ...
# ...

# %%
filtered_df['Job Title'].unique()
# Out:
# array(['Software Quality Assurance Engineer',
#        'Senior Software Quality Assurance Engineer',
#        'Software Development Engineer in Test (SDET)',
#        'Senior QA Engineer', 'Software Quality Assurance Analyst',
#        'Hybrid QA for financial software', 'SQA Engineer',
#        'Senior SQA Engineer - Automation',
#        'Principal Software Quality Assurance Engineer',
#        'SQA Engineer - Mobile', 'Senior SQA Engineer', 'SQA',
#        'Software Engineer, QA', 'Associate SQA Engineer',
#        'Junior Software Quality Assurance Engineer', 'Sr.SQA Engineer',
#        'Hybrid QA for financial software 2', 'SQA Engineer (Team Lead)',
#        'QA Engineer', 'QA Engineer - Manual', 'QA Engineer - Mobile',
#        'Software Quality Assurance Manager', 'Sr. SQAE Automation',
#        'SQA Analyst', 'Software Quality Assurance (Manual) - Pakistan',
#        'Senior Software Development Engineer in Test - Data Analytics',
# ...

# %%
conndition=df['Job Title'].str.contains(it_tech_pattern, case=False)
df.loc[conndition, 'Job Title_2'] = 'Software Quality Assurance and Testing Engineer'

# %%
df[df['Job Title_2']=='Software Quality Assurance and Testing Engineer']['Job Title_2']
# Out:
# 4      Software Quality Assurance and Testing Engineer
# 8      Software Quality Assurance and Testing Engineer
# 11     Software Quality Assurance and Testing Engineer
# 14     Software Quality Assurance and Testing Engineer
# 15     Software Quality Assurance and Testing Engineer
#                             ...
# 652    Software Quality Assurance and Testing Engineer
# 682    Software Quality Assurance and Testing Engineer
# 712    Software Quality Assurance and Testing Engineer
# 724    Software Quality Assurance and Testing Engineer
# 730    Software Quality Assurance and Testing Engineer
# Name: Job Title_2, Length: 94, dtype: object

# %% [raw]
# 'Program Officer - SBCC - Qadam Ba Qadam Project' is here

# %%
df['Job Title_2'].isnull().sum()
# Out:
# 0

# %%
df[df['Job Title_2'].isnull()]['Job Title'].unique()
# Out:
# array([], dtype=object)

# %%
df['Job Title_2'].unique()
# Out:
# array(['Software Engineer',
#        'Software Quality Assurance and Testing Engineer'], dtype=object)

# %%
len(df['Job Title_2'].unique())
# Out:
# 2

# %%
df['Job Title_2'].value_counts()
# Out:
# Job Title_2
# Software Engineer                                  639
# Software Quality Assurance and Testing Engineer     94
# Name: count, dtype: int64

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
