# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime

# %%
path='Filltered_Files-concatenated/IT_roles_Linkedin_Job_Details_and_Job_Descriptions_26-sep-to-26-nov_4690-jobs-1856_titles_v5_Feature_Eng_Processed.csv'
path
# Out:
# 'Filltered_Files-concatenated/IT_roles_Linkedin_Job_Details_and_Job_Descriptions_26-sep-to-26-nov_4690-jobs-1856_titles_v5_Feature_Eng_Processed.csv'

# %%
df=pd.read_csv(path)
df
# Out:
#                                               Job Title  \
# 0                                            iOS Intern
# 1                                 Trainee iOS Developer
# 2                                     Android Developer
# 3                       MERN and React Native Developer
# 4                          Mobile Application Developer
# ...                                                 ...
# 4685  Lead Software Engineer, Trilogy (Remote) - $10...
# 4686  Senior C++ Software Engineer, GFI Software (Re...
# 4687                                        QA Engineer
# 4688  Principal Software Engineer, IgniteTech (Remot...
# 4689    Software Development Support Engineer (L2 & L3)
#
#                                                Job Info  \
# 0     AusSource Enterprises (SMC-PRIVATE) LIMITED · ...
# 1     TechSwivel (Private) Limited · Lahore, Punjab,...
# 2     MWAN Mobile · Islāmābād, Pakistan (On-site)  \...
# 3     TecStik · Karāchi, Sindh, Pakistan (On-site)  ...
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Job Info', 'Job Type', 'Job Link_x', 'employees',
#        'Job ID', 'Job Link_y', 'Job Desception', 'Company Info', 'company',
#        'location_1', 'location_2', 'Remote/Onsite', 'n_applicant',
#        'job posting time', 'Job Type nElements', 'Job-Type',
#        'Experience Level', 'Comp_N_Employees', 'Comp_Industry'],
#       dtype='object')

# %% [markdown]
# ### checking duplicates

# %%
len(df)
# Out:
# 4690

# %%
len(df['Job ID'].unique())
# Out:
# 3734

# %%
duplicates_count=df.duplicated(subset=['Job ID']).sum()
duplicates_count
# Out:
# 956

# %%
duplicates = df['Job ID'].duplicated()
df[duplicates]
# Out:
#                                               Job Title  \
# 237                        Mobile Application Developer
# 243                       Flutter Application Developer
# 244   Mobile Application Developer (iOS, Swift), gt....
# 249   Mobile Application Developer (iOS, Swift), gt....
# 251          Senior Mobile and AI Application Developer
# ...                                                 ...
# 4677                     Senior Software Engineer (PHP)
# 4678  Software Engineer (AI-Powered Development), Tr...
# 4679                          Software Engineer_Node JS
# 4681                                        SQA Analyst
# 4686  Senior C++ Software Engineer, GFI Software (Re...
#
#                                                Job Info  \
# 237   Analytica · Lahore, Punjab, Pakistan (On-site)...
# 243   Eigix IT Solutions · Multan, Punjab, Pakistan ...
# 244   Crossover  · Lahore, Punjab, Pakistan (Remote)...
# 249   Crossover  · Lahore, Punjab, Pakistan (Remote)...
# ...

# %% [markdown]
# ### drop duplicates

# %%
df = df.drop_duplicates(subset=['Job ID'])

# %%
df.shape
# Out:
# (3734, 20)

# %%
n_titles=len(df['Job Title'].unique())
n_titles
# Out:
# 1856

# %%
saving_path=path.split('_26-sep-to-26-nov_')[0]+'_26-sep-to-26-nov_'+f'{len(df)}-jobs_{n_titles}-titles_{df.shape[1]}-features_Not-duplicated_v5_Feature_Eng_Processed.csv'
saving_path
# Out:
# 'Filltered_Files-concatenated/IT_roles_Linkedin_Job_Details_and_Job_Descriptions_26-sep-to-26-nov_3734-jobs_1856-titles_20-features_Not-duplicated_v5_Feature_Eng_Processed.csv'

# %%
df.to_csv(saving_path,index=False)
