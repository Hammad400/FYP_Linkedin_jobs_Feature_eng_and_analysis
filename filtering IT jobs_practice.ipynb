# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Files used in current analysis/Linkedin_Job_Details_26-Sep-2023-to-09-Oct-2023_4214-jobs_181-pages.csv')
df
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 4209         Oracle Apps DBA - R12 (Full Customization)
# 4210                Engineer, Service-to-Service Fabric
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4212                               Senior IOS Developer
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %% [raw]
# it_tech_pattern = 'IT'
# filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df.dropna(inplace=True)

# %%
df['Job ID']=df['Job Link'].apply(lambda x:int(x.split('/')[5]))

# %%
df = df.drop_duplicates(subset=['Job ID'])

# %%
df.shape
# Out:
# (3573, 6)

# %%
import pandas as pd
weather_data = {
    'words': ['with', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}
df2 = pd.DataFrame(weather_data)
df2
# Out:
#    words
# 0   with
# 1  Sunny
# 2   Snow
# 3   Snow
# 4   Rain
# 5  Sunny

# %%
it_tech_pattern = 'IT'
filtered_df2 = df2[df2['words'].str.contains(it_tech_pattern, case=False)]
filtered_df2
# Out:
#   words
# 0  with

# %%
it_tech_pattern = 'sunny'
filtered_df2 = df2[df2['words'].str.contains(it_tech_pattern, case=False)]
filtered_df2
# Out:
#    words
# 1  Sunny
# 5  Sunny

# %% [raw]
# it_tech_pattern = ['sunny','IT']
# filtered_df2 = df2[df2['words'].str.contains(it_tech_pattern, case=False)]
# filtered_df2
# TypeError: unhashable type: 'list'

# %%
it_tech_pattern = 'sunny|IT'
filtered_df2 = df2[df2['words'].str.contains(it_tech_pattern, case=False)]
filtered_df2
# Out:
#    words
# 0   with
# 1  Sunny
# 5  Sunny

# %%
it_tech_pattern = 'sunny|IT|in|sn'
filtered_df2 = df2[df2['words'].str.contains(it_tech_pattern, case=False)]
filtered_df2
# Out:
#    words
# 0   with
# 1  Sunny
# 2   Snow
# 3   Snow
# 4   Rain
# 5  Sunny

# %%
it_tech_keywords = ['IT']

# Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
filtered_df2 = df2[df2['words'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df2
# Out:
# Empty DataFrame
# Columns: [words]
# Index: []

# %%
it_tech_keywords = ['it','now','Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist']

# Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
filtered_df2 = df2[df2['words'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df2
# Out:
#   words
# 0  with
# 2  Snow
# 3  Snow

# %%
it_tech_pattern = 'IT'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
len(filtered_df)
filtered_df['Job Title'].unique()
len(filtered_df['Job Title'].unique())
# Out:
# 374

# %%
it_tech_keywords = ['IT','it','It']

filtered_df = df[df['Job Title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df
len(filtered_df)
filtered_df['Job Title'].unique()
len(filtered_df['Job Title'].unique())
# Out:
# 374

# %%
it_tech_pattern = 'IT'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=True)]
filtered_df
len(filtered_df)
filtered_df['Job Title'].unique()
# len(filtered_df['Job Title'].unique())
# Out:
# array(['IT Jobs', 'SEO Executive (ON-SITE)',
#        'Senior Associate - IT Auditor',
#        'Team Lead IT Software Development (m/f/d)',
#        'IT Data Migration Specialist (m/f/d) - 100% remote',
#        'Director IT', 'Manager Customer Facing IT', 'IT Sales Executive',
#        'Senior Full-stack Java / Angular Developer - +10 years of IT experience - Full remote - Contractor in USD',
#        'IT Support Coordinator Intern', 'IT & Network Administrator',
#        'Assistant Manager IT', 'Project Manager - IT Services',
#        'Executive IT Infrastructure',
#        'Senior Executive IT Infrastructure',
#        'Manager IT BP - Digital Channels',
#        'Assistant Manager IT Infrastructure',
#        'IT Manager - Data Engineer',
#        'Assistant Manager IT (Microsoft Dynamics)', 'IT Executive',
#        'IT Project Manager', 'Chief Manager - IT Risk'], dtype=object)

# %%
it_tech_keywords = ['IT']

filtered_df = df[df['Job Title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df
len(filtered_df)
filtered_df['Job Title'].unique()
len(filtered_df['Job Title'].unique())
# Out:
# 22

# %%
it_tech_pattern = 'Tech'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                               Job Title  \
# 42                           Technical Business Analyst
# 47                      Fintech B2B Marketing Executive
# 124   Senior Technical Support Engineer, Skyvera (Re...
# 155                                 Technical Recruiter
# 176                               ERP Technical Support
# ...                                                 ...
# 3905                            Senior Technical Writer
# 3990  Strategic Business Unit – Technical & Business...
# 4014           Electronic Technician (Sukkur, Pakistan)
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 42    UHF Solutions Pvt Ltd · Karachi Division, Sind...
# 47    IMarkPlace · Karachi Division, Sindh, Pakistan...
# 124   Crossover  · Peshawar, Khyber Pakhtunkhwa, Pak...
# 155   HR Force Int. · Lahore, Punjab, Pakistan (On-s...
# ...

# %%
filtered_df['Job Title'].unique()
# checking if Teh then it is IT or not
# Out:
# array(['Technical Business Analyst', 'Fintech B2B Marketing Executive',
#        'Senior Technical Support Engineer, Skyvera (Remote) - $30,000/year USD',
#        'Technical Recruiter', 'ERP Technical Support',
#        'Technical Content Writer',
#        'ASSISTANT MANAGER COMPLIANCE- INFORMATION TECHNOLOGY',
#        'Technical Writer', 'Dynamics 365 F&O Technical Consultant',
#        'Technical Customer Support Specialist',
#        'Technical Project Manager', 'Cloud Technical Specialist',
#        'Technical Project Manager/ Scrum Master',
#        'Engineering Technician', 'Radiologic Technologist',
#        'Technical Lead - .NET', 'Senior Technical Project Manager',
#        'Technical Advisor for Development of Women Entrepreneurship Policy - Islamabad',
#        'Technical Product Manager',
#        'Senior Technical Support Analyst, Skyvera (Remote) - $30,000/year USD',
#        'Technical Advisor Environmental Health - Asia',
#        'Technical Sales Representative',
# ...

# %%
it_tech_pattern = 'Information Technology'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                               Job Title  \
# 182   ASSISTANT MANAGER COMPLIANCE- INFORMATION TECH...
# 1943            Information Technology Business Partner
# 1990          Information Technology Functional Partner
# 2016           Information Technology Help Desk Manager
# 2495                      Information Technology Intern
# 2609             Information Technology Sales Executive
# 2636             Information Technology Project Manager
# 2862            Information Technology Support Engineer
# 2869                      Information Technology Intern
# 3068            Information Technology Business Analyst
# 3224         Information Technology Coordinator - Sales
# 3843            Information Technology Security Manager
#
#                                                Job Info  \
# 182   HCMS Global · Karachi Division, Sindh, Pakista...
# 1943  Packages Group · Lahore, Punjab, Pakistan (On-...
# 1990  Packages Group · Lahore, Punjab, Pakistan (On-...
# ...

# %%
it_tech_pattern = 'Tech|Information Technology|Developer|Software Engineer|Data Scientist|Software'
filtered_df = df[df['Job Title'].str.contains(it_tech_pattern, case=False)]
filtered_df
# Out:
#                                               Job Title  \
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# 18                               Dotnet+React Developer
# 20                    Artificial Intelligence Developer
# ...                                                 ...
# 4194  Senior Software Engineer - .NET (6-months cont...
# 4208                      Senior Java Software Engineer
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4212                               Senior IOS Developer
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# 4     ItCreaters · Lahore, Punjab, Pakistan (On-site...
# 18         Macrosoft · Pakistan (Remote)  \n2 weeks ago
# ...

# %%
it_tech_keywords = ['Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist','Software']
filtered_df = df[df['Job Title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df
# Out:
#                                               Job Title  \
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# 18                               Dotnet+React Developer
# 20                    Artificial Intelligence Developer
# ...                                                 ...
# 4194  Senior Software Engineer - .NET (6-months cont...
# 4208                      Senior Java Software Engineer
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4212                               Senior IOS Developer
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# 4     ItCreaters · Lahore, Punjab, Pakistan (On-site...
# 18         Macrosoft · Pakistan (Remote)  \n2 weeks ago
# ...

# %%
# 'IT'.lower()
# Out:
# 'it'

# %%
# 'SQL Database Developer'.lower()
# Out:
# 'sql database developer'

# %%
it_tech_keywords = ['IT','Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist','Software']
filtered_df = df[df['Job Title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
filtered_df
# Out:
#                                               Job Title  \
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# 18                               Dotnet+React Developer
# 20                    Artificial Intelligence Developer
# ...                                                 ...
# 4194  Senior Software Engineer - .NET (6-months cont...
# 4208                      Senior Java Software Engineer
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4212                               Senior IOS Developer
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# 4     ItCreaters · Lahore, Punjab, Pakistan (On-site...
# 18         Macrosoft · Pakistan (Remote)  \n2 weeks ago
# ...

# %%
filtered_df['Job Title'].unique()
# Out:
# array(['SQL Database Developer', 'Business Intelligence Developer',
#        'Web Developer - Internship', 'Dotnet+React Developer',
#        'Artificial Intelligence Developer', 'Software Engineer',
#        'Junior Business Developer', 'Jr Business Developer (Upwork)',
#        'Software Engineer - Product Operation', 'IT Jobs',
#        'Technical Business Analyst', 'Full Stack Developer',
#        'Python Developer with Data Science Focus', 'Odoo Developer',
#        'Web Developer', 'Salesforce Developer',
#        'Software Quality Assurance Engineer', 'Senior Software Engineer',
#        'SEO Developer',
#        'Senior Technical Support Engineer, Skyvera (Remote) - $30,000/year USD',
#        'Software Engineer-Integration', 'Python/Django Developer',
#        'Technical Recruiter', 'Application Developer',
#        'Back End Developer', 'SEO Executive (ON-SITE)',
#        'ERP Technical Support', 'Shopify Developer',
# ...

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
