# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### reading Feature Eng processed csv file

# %%
df=pd.read_csv('Feature Eng processed Files/Linkedin_Job_Details_and_Descriptions_26-Sep-2023-to-26-Nov-202311737-jobs_20-features_685-pages_Feature-Eng-processed_v5.csv')

# %% [markdown]
# ***This file have no duplicates and no missing values in Job details featues***

# %%
df
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df.shape
# Out:
# (11737, 20)

# %%
df.isnull().sum()
# Out:
# Job Title                0
# Job Info                 0
# Job Type                 0
# Job Link_x               0
# employees                0
# Job ID                   0
# Job Link_y               0
# Job Desception          31
# Company Info          2916
# company                  0
# location_1               0
# location_2               0
# Remote/Onsite            0
# n_applicant           4686
# job posting time         0
# Job Type nElements       0
# Job-Type                 0
# Experience Level         0
# Comp_N_Employees         0
# Comp_Industry            0
# dtype: int64

# %%
df_3=df.copy()

# %%
df_4=df_3.dropna(subset=['Job Desception'])
df_4
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_4.shape
# Out:
# (11706, 20)

# %%
df_4_uncomplete_desc_IDs=[]
for i in range(0,len(df_4.iloc[:])):
    if len(df_4.iloc[i]['Job Desception'])<20:
        df_4_uncomplete_desc_IDs.append(df_4.iloc[i]['Job ID'])

# %%
df_4_uncomplete_desc_IDs
len(df_4_uncomplete_desc_IDs)
# Out:
# 1125

# %%
df_4_uncomp_desc=df_4[df_4['Job ID'].isin(df_4_uncomplete_desc_IDs)]
df_4_uncomp_desc
# Out:
#                                                Job Title  \
# 23              Digital Marketing Strategist and Planner
# 136                        Software Engineer-Integration
# 400                                      DevOps Engineer
# 433                              Real Estate Sales Agent
# 440                                Google Ads Specialist
# ...                                                  ...
# 11731  Senior Consultant- Business Consulting- Intern...
# 11732                                    Unity Developer
# 11734                    Information Security Specialist
# 11735          FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                                Community Associate
#
#                                                 Job Info  \
# 23     Prime Human Resource Services (Pvt) Ltd · Karā...
# 136    People (Professional Employers Pvt Ltd) · Isla...
# 400    TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# ...

# %%
df_5=df_4.drop(df_4_uncomp_desc.index)
df_5
# Out:
#                                                Job Title  \
# 0                                LinkedIn Data Extractor
# 1                                   It Management Intern
# 2                                 SQL Database Developer
# 3                        Business Intelligence Developer
# 4                             Web Developer - Internship
# ...                                                  ...
# 11727                 Technical Sales Support Specialist
# 11728                           YouTube Channel Producer
# 11729  Social Media Content Creator - Night Shift wit...
# 11730                                Design Sales agents
# 11733    Manager – Growth Chat & SMS (Digital Marketing)
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# ...

# %%
# df_2[df_2['Job ID']==3769970428] for verification

# %% [markdown]
# #### using commen keywords used in IT and Tech

# %%
Software_Eng_keywords_all=['Software Engineer','Software Developer','Software/Application Developer','Software Development',
                           'Software Quality Assurance','Software Architect','Software Project Manager','QA',
                           'Software Test Engineer','Software Engineering','Software Trainee Engineer',
                           'Software Document Writer','Software Delivery Engineer','Software Support Manager',
                           'Product Specialist - Software Solutions',
                           'Software Services Lead','Software Project Coordinator',
                           'SDDC Consultant (Software-Defined Data Center)','Software Solutions Architect',
                           'Hardware/Software Tester','Software Support Engineer', 'Engineering Manager, GFI Software',
                           'Fellow of GenAI Software Excellence','Pre-Sales Software']
Software_Eng_keywords_all
len(Software_Eng_keywords_all)

filtered_df_3_title = df_3[df_3['Job Title'].apply(lambda title: any(keyword.lower() in title.lower() for keyword in Software_Eng_keywords_all))]
filtered_df_3_title
# Out:
#                                                Job Title  \
# 25                                     Software Engineer
# 33                 Software Engineer - Product Operation
# 65                                    SOFTWARE DEVELOPER
# 79                                     Software Engineer
# 92                   Software Quality Assurance Engineer
# ...                                                  ...
# 11683  Lead Software Engineer, Trilogy (Remote) - $10...
# 11691  Senior C++ Software Engineer, GFI Software (Re...
# 11708                                        QA Engineer
# 11720  Principal Software Engineer, IgniteTech (Remot...
# 11725    Software Development Support Engineer (L2 & L3)
#
#                                                 Job Info  \
# 25     Jin Technologies Private Limited · Islamabad, ...
# 33     i2c Inc. · Lahore, Punjab, Pakistan (On-site) ...
# 65     360 TECHNOLOGIES · Islamabad, Islāmābād, Pakis...
# ...

# %%
filtered_df_3_title['Job Title'].unique()
# len(filtered_df_3_title['Job Title'].unique())
# Out:
# array(['Software Engineer', 'Software Engineer - Product Operation',
#        'SOFTWARE DEVELOPER', 'Software Quality Assurance Engineer',
#        'Senior Software Engineer', 'Software Engineer-Integration',
#        'Professional, QA',
#        'AI-Augmented Software Developer, Trilogy (Remote) - $200,000/year USD',
#        'Senior Software Quality Assurance Engineer',
#        'Software Development Engineer in Test (SDET)',
#        'Software Developer', 'Software Engineer - Marketing Platform',
#        'Senior QA Engineer',
#        'Senior Software Development Project Manager',
#        'Software Quality Assurance Analyst',
#        'Software Architect Lead Developer',
#        'Software Engineer (.Net/MVC)', 'Principal Software Engineer',
#        'Senior Software Engineer (.NET/ React Js)',
#        'Principal Software Engineer Full Stack PHP',
#        'Senior Java Software Engineer',
#        'Team Lead IT Software Development (m/f/d)',
# ...

# %%
titles_to_drop_old=['Civil Engineers (Roads, QA/QC) QS','Business Development Manager (Software Development Services)']

# %%
Un_QA_titles=['Technical Advisor - Family Planning - Qadam Ba Qadam Project','Program & Administrative Assistant - Qadam Ba Qadam Project',
              'Administrative Assistant - Qadam Ba Qadam Project',
              'Social Behavior Change Communication Specialist - Qadam Ba Qadam Project',
              'Employee Service Executive - Qasba Gujrat (H-164)','Professional, QA']
Un_QA_titles
# Out:
# ['Technical Advisor - Family Planning - Qadam Ba Qadam Project',
#  'Program & Administrative Assistant - Qadam Ba Qadam Project',
#  'Administrative Assistant - Qadam Ba Qadam Project',
#  'Social Behavior Change Communication Specialist - Qadam Ba Qadam Project',
#  'Employee Service Executive - Qasba Gujrat (H-164)',
#  'Professional, QA']

# %%
titles_to_drop=titles_to_drop_old+Un_QA_titles
titles_to_drop
len(titles_to_drop)
# Out:
# 8

# %%
df_3_Software_Eng=filtered_df_3_title[~filtered_df_3_title['Job Title'].isin(titles_to_drop)]
df_3_Software_Eng
len(df_3_Software_Eng)
len(df_3_Software_Eng['Job Title'].unique())
# Out:
# 304

# %%
path='Filltered_Files/software_engineer_26_sep_to_26_nov_735_jobs_304_titles_v5_Feature_Eng_Processed.csv'

# %%
# df_3_Software_Eng.to_csv(path,index=False)

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
