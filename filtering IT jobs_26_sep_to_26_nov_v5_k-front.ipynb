# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### reading Feature Eng processed csv file

# %%
df=pd.read_csv('Feature Eng processed Files/Linkedin_Job_Details_and_Descriptions_26-Sep-2023-to-26-Nov-202311737-jobs_20-features_685-pages_Feature-Eng-processed_v5.csv')

# %% [markdown]
# ***This file have no duplicates and no missing values in Job details featues***

# %%
df
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df.shape
# Out:
# (11737, 20)

# %%
df.isnull().sum()
# Out:
# Job Title                0
# Job Info                 0
# Job Type                 0
# Job Link_x               0
# employees                0
# Job ID                   0
# Job Link_y               0
# Job Desception          31
# Company Info          2916
# company                  0
# location_1               0
# location_2               0
# Remote/Onsite            0
# n_applicant           4686
# job posting time         0
# Job Type nElements       0
# Job-Type                 0
# Experience Level         0
# Comp_N_Employees         0
# Comp_Industry            0
# dtype: int64

# %%
df_3=df.copy()

# %%
df_4=df_3.dropna(subset=['Job Desception'])
df_4
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_4.shape
# Out:
# (11706, 20)

# %%
df_4_uncomplete_desc_IDs=[]
for i in range(0,len(df_4.iloc[:])):
    if len(df_4.iloc[i]['Job Desception'])<20:
        df_4_uncomplete_desc_IDs.append(df_4.iloc[i]['Job ID'])

# %%
df_4_uncomplete_desc_IDs
len(df_4_uncomplete_desc_IDs)
# Out:
# 1125

# %%
df_4_uncomp_desc=df_4[df_4['Job ID'].isin(df_4_uncomplete_desc_IDs)]
df_4_uncomp_desc
# Out:
#                                                Job Title  \
# 23              Digital Marketing Strategist and Planner
# 136                        Software Engineer-Integration
# 400                                      DevOps Engineer
# 433                              Real Estate Sales Agent
# 440                                Google Ads Specialist
# ...                                                  ...
# 11731  Senior Consultant- Business Consulting- Intern...
# 11732                                    Unity Developer
# 11734                    Information Security Specialist
# 11735          FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                                Community Associate
#
#                                                 Job Info  \
# 23     Prime Human Resource Services (Pvt) Ltd · Karā...
# 136    People (Professional Employers Pvt Ltd) · Isla...
# 400    TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# ...

# %%
df_5=df_4.drop(df_4_uncomp_desc.index)
df_5
# Out:
#                                                Job Title  \
# 0                                LinkedIn Data Extractor
# 1                                   It Management Intern
# 2                                 SQL Database Developer
# 3                        Business Intelligence Developer
# 4                             Web Developer - Internship
# ...                                                  ...
# 11727                 Technical Sales Support Specialist
# 11728                           YouTube Channel Producer
# 11729  Social Media Content Creator - Night Shift wit...
# 11730                                Design Sales agents
# 11733    Manager – Growth Chat & SMS (Digital Marketing)
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# ...

# %% [markdown]
# #### using commen keywords used in IT and Tech

# %%
it_tech_keywords=['Front']
it_tech_keywords
len(it_tech_keywords)

filtered_df_3_title = df_3[df_3['Job Title'].apply(lambda title: any(keyword.lower() in title.lower() for keyword in it_tech_keywords))]
filtered_df_3_title
# Out:
#                                 Job Title  \
# 322    Front Sales & Support (Bark & PPC)
# 368              FDO - Front Desk Officer
# 514            Frontend Vue j.s developer
# 601                    Frontend Developer
# 626               Front Desk Receptionist
# ...                                   ...
# 11581             Web Front-end Developer
# 11616             Web Front-End Developer
# 11625              Web Frontend Developer
# 11636              Web Frontend Developer
# 11674        Angular - Frontend Developer
#
#                                                 Job Info  \
# 322    NX3 Digital · Karāchi, Sindh, Pakistan (On-sit...
# 368    La Forma Specialist Clinic · Lahore, Punjab, P...
# 514    HR Ways - Hiring Tech Talent · Lahore, Punjab,...
# 601    Marshmallow Advertising Pvt. Ltd. · Lahore, Pu...
# 626    Kamayi · Karāchi, Sindh, Pakistan (On-site)  \...
# ...                                                  ...
# ...

# %%
filtered_df_3_title['Job Title'].unique()
# Out:
# array(['Front Sales & Support (Bark & PPC)', 'FDO - Front Desk Officer',
#        'Frontend Vue j.s developer', 'Frontend Developer',
#        'Front Desk Receptionist', 'Front-End Developer',
#        'Front-End Engineer', 'Manager Frontend App Development',
#        'International Sales Executive (Front Seller)',
#        'Front-End Software Engineer', 'Front End Shopify Developer',
#        'Front seller-Bark Expert',
#        'Front-End Engineer - Site Speed Optimization',
#        'Software Engineer Frontend', 'Front-End Web Development Engineer',
#        'International Front Sales Executive',
#        'Front Sales Executive for UK Market',
#        'Internship Program - Angular frontend developer',
#        'Lead Site Speed Optimization Developer - Front End Engineer',
#        'Front Desk Representative', 'Senior Frontend Developer',
#        'VUE JS Front End Developer', 'Front End Angular Developer',
#        'Principle Software Engineer (Frontend)', 'Front Ebook Sales',
# ...

# %%
len(filtered_df_3_title['Job Title'].unique())
# Out:
# 105

# %%
titles_to_drop=['Front Sales & Support (Bark & PPC)',
     'FDO - Front Desk Officer',
     'Front Desk Receptionist',
     'International Sales Executive (Front Seller)',
     'Front seller-Bark Expert',
     'International Front Sales Executive',
     'Front Sales Executive for UK Market',
     'Front Desk Representative',
     'Front Ebook Sales',
     'Front Desk Officer',
     'Front Sales Executive (Bark)',
     'Front sales Design',
     'Front Desk - DHA RAYA Office',
     'Bark Front Sales Specialist',
     'Front Sales E-books',
     'Front Seller - Bark',
     'Front Sales(Bark)',
     'Front Sales',
     'Front Desk Officer- Males',
     'Front Sales Specialist',
     'Front Seller',
     'Front Sales - Mobile Apps',
     'Front Sales Resource',
     'Front Sales Lead',
     'Instructor Front Desk Office',
     'Design Sales Specialist - Front Sale | Up Sell',
     'Operation/Front desk Officer',
     'Front sales (Bark)',
     'Front Sales - Design Team',
     'Front Sales Discord & Twitch',
     'Business Development Executive (Front Sales)',
     'Front Bark/Sales Specialist',
     'Front Desk Associate',
     'Front Sale Executive (Design)',
     'Front Seller, Up Seller and Bidder Required for Bark / Upwork / Fiverr',
     'Mobile Applications Front Sales Specialist',
     'Twitter Bidder/ Front seller',
     'Front Desk Officer (H-270)',
     'Front Desk Coordinator']
titles_to_drop
len(titles_to_drop)
# Out:
# 39

# %%
df_3_filtered=filtered_df_3_title[~filtered_df_3_title['Job Title'].isin(titles_to_drop)]
df_3_filtered
len(df_3_filtered)
# Out:
# 114

# %%
len(df_3_filtered['Job Title'].unique())
# Out:
# 66

# %%
path=f"Filltered_Files/k-Front_26_sep_to_26_nov_{len(df_3_filtered)}_jobs_{len(df_3_filtered['Job Title'].unique())}_titles_v5_Feature_Eng_Processed.csv"
path
# Out:
# 'Filltered_Files/k-Front_26_sep_to_26_nov_114_jobs_66_titles_v5_Feature_Eng_Processed.csv'

# %%
df_3_filtered.to_csv(path,index=False)

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
