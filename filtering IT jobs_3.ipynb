# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Files used in current analysis/Linkedin_Job_Details_26-Sep-2023-to-09-Oct-2023_4214-jobs_181-pages.csv')
df
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 4209         Oracle Apps DBA - R12 (Full Customization)
# 4210                Engineer, Service-to-Service Fabric
# 4211  Technical Product Manager (OTE $80,000/year US...
# 4212                               Senior IOS Developer
# 4213  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_=pd.read_csv('Files used in current analysis/Linkedin_Job-Descriptions-company_details_26-Sep-2023-to-26-Nov-2023_15947-jobs_685-pages.csv')
df_
# Out:
#                                             Job Link  \
# 0      https://www.linkedin.com/jobs/view/3727054368
# 1      https://www.linkedin.com/jobs/view/3723395858
# 2      https://www.linkedin.com/jobs/view/3727034665
# 3      https://www.linkedin.com/jobs/view/3727029273
# 4      https://www.linkedin.com/jobs/view/3727034696
# ...                                              ...
# 15942  https://www.linkedin.com/jobs/view/3767355025
# 15943  https://www.linkedin.com/jobs/view/3766809535
# 15944  https://www.linkedin.com/jobs/view/3772530977
# 15945  https://www.linkedin.com/jobs/view/3771943212
# 15946  https://www.linkedin.com/jobs/view/3767944844
#
#                                           Job Desception  \
# 0      About the job\n            \n\n \nAbout Us:We ...
# 1      About the job\n            \n\n \nWe are looki...
# 2      About the job\n            \n\n \nCompany Over...
# 3      About the job\n            \n\n \nBI Developer...
# ...

# %%
df_1=pd.read_csv('Files used in current analysis/Linkedin_Job_Details_26-Sep-2023-to-26-Nov-2023_15875-jobs_685-pages.csv')
df_1
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 15870  Manager – Growth Chat & SMS (Digital Marketing)
# 15871                         Release Support Engineer
# 15872                  Information Security Specialist
# 15873        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 15874                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df['Job ID']=df['Job Link'].apply(lambda x:int(x.split('/')[5]))
df_['Job ID']=df_['Job Link'].apply(lambda x:int(x.split('/')[5]))
df_1['Job ID']=df_1['Job Link'].apply(lambda x:int(x.split('/')[5]))

# %%
df_2=df_[df_['Job ID'].isin(df['Job ID'])]
df_2
# Out:
#                                             Job Link  \
# 0      https://www.linkedin.com/jobs/view/3727054368
# 1      https://www.linkedin.com/jobs/view/3723395858
# 2      https://www.linkedin.com/jobs/view/3727034665
# 3      https://www.linkedin.com/jobs/view/3727029273
# 4      https://www.linkedin.com/jobs/view/3727034696
# ...                                              ...
# 15679  https://www.linkedin.com/jobs/view/3729723124
# 15681  https://www.linkedin.com/jobs/view/3537348803
# 15766  https://www.linkedin.com/jobs/view/3661745501
# 15776  https://www.linkedin.com/jobs/view/3728757956
# 15915  https://www.linkedin.com/jobs/view/3734537706
#
#                                           Job Desception  \
# 0      About the job\n            \n\n \nAbout Us:We ...
# 1      About the job\n            \n\n \nWe are looki...
# 2      About the job\n            \n\n \nCompany Over...
# 3      About the job\n            \n\n \nBI Developer...
# ...

# %%
df_3=pd.merge(df,df_,on='Job ID',how='inner')
df_3
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 7267                Engineer, Service-to-Service Fabric
# 7268  Technical Product Manager (OTE $80,000/year US...
# 7269                               Senior IOS Developer
# 7270                               Senior IOS Developer
# 7271  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
# why df3 have 7272 rows

# %%
# df3=df[df['Job ID']==df_['Job ID']]
# df3
# ValueError: Can only compare identically-labeled Series objects

# %%
df_2.drop_duplicates(subset=['Job ID']).shape
# Out:
# (3623, 4)

# %%
df.drop_duplicates(subset=['Job ID']).shape
# Out:
# (3623, 6)

# %%
df_3.drop_duplicates(subset=['Job ID']).shape
# Out:
# (3623, 9)

# %%
df.isnull().sum()
# Out:
# Job Title    54
# Job Info     54
# Job Type     54
# Job Link      0
# employees    54
# Job ID        0
# dtype: int64

# %%
df_3.isnull().sum()
# Out:
# Job Title          67
# Job Info           67
# Job Type           67
# Job Link_x          0
# employees          67
# Job ID              0
# Job Link_y          0
# Job Desception    104
# Company Info      915
# dtype: int64

# %%
df_3.columns
# Out:
# Index(['Job Title', 'Job Info', 'Job Type', 'Job Link_x', 'employees',
#        'Job ID', 'Job Link_y', 'Job Desception', 'Company Info'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df_1.dropna(inplace=True)
df_3.dropna(subset=['Job Title','Job Info','Job Type','employees'],inplace=True) # i want to delete specific columns

# %%
# df['Job ID']=df['Job Link'].apply(lambda x:int(x.split('/')[5]))

# %%
df = df.drop_duplicates(subset=['Job ID'])
df_1=df_1.drop_duplicates(subset=['Job ID'])
df_2=df_2.drop_duplicates(subset=['Job ID'])
df_3=df_3.drop_duplicates(subset=['Job ID'])

# %%
df.shape,df_1.shape,df_2.shape,df_3.shape
# Out:
# ((3573, 6), (11744, 6), (3623, 4), (3573, 9))

# %%
df_2
# Out:
#                                            Job Link  \
# 0     https://www.linkedin.com/jobs/view/3727054368
# 1     https://www.linkedin.com/jobs/view/3723395858
# 2     https://www.linkedin.com/jobs/view/3727034665
# 3     https://www.linkedin.com/jobs/view/3727029273
# 4     https://www.linkedin.com/jobs/view/3727034696
# ...                                             ...
# 4210  https://www.linkedin.com/jobs/view/3734517227
# 4211  https://www.linkedin.com/jobs/view/3730554639
# 4212  https://www.linkedin.com/jobs/view/3731001750
# 4213  https://www.linkedin.com/jobs/view/3736179533
# 4214  https://www.linkedin.com/jobs/view/3731006178
#
#                                          Job Desception  \
# 0     About the job\n            \n\n \nAbout Us:We ...
# 1     About the job\n            \n\n \nWe are looki...
# 2     About the job\n            \n\n \nCompany Over...
# 3     About the job\n            \n\n \nBI Developer...
# ...

# %%
df_3
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 7266         Oracle Apps DBA - R12 (Full Customization)
# 7267                Engineer, Service-to-Service Fabric
# 7268  Technical Product Manager (OTE $80,000/year US...
# 7269                               Senior IOS Developer
# 7271  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_4=df_4=df_3.dropna(subset=['Job Desception'])
df_4
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 7266         Oracle Apps DBA - R12 (Full Customization)
# 7267                Engineer, Service-to-Service Fabric
# 7268  Technical Product Manager (OTE $80,000/year US...
# 7269                               Senior IOS Developer
# 7271  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_4.shape
# Out:
# (3542, 9)

# %%
df_4_uncomplete_desc_IDs=[]
for i in range(0,len(df_4.iloc[:])):
    if len(df_4.iloc[i]['Job Desception'])<20:
        df_4_uncomplete_desc_IDs.append(df_4.iloc[i]['Job ID'])

# %%
df_4_uncomplete_desc_IDs
len(df_4_uncomplete_desc_IDs)
# Out:
# 66

# %%
df_4_uncomp_desc=df_4[df_4['Job ID'].isin(df_4_uncomplete_desc_IDs)]
df_4_uncomp_desc
# Out:
#                                               Job Title  \
# 93             Digital Marketing Strategist and Planner
# 265                       Software Engineer-Integration
# 651                                     DevOps Engineer
# 692                             Real Estate Sales Agent
# 699                               Google Ads Specialist
# ...                                                 ...
# 6375  Junior PR Specialist (Remote Internship – Publ...
# 6729                             React Native Developer
# 6733                                    Finance Manager
# 6960                                 IT Project Manager
# 7169                      Talent Acquisition Specialist
#
#                                                Job Info  \
# 93    Prime Human Resource Services (Pvt) Ltd · Karā...
# 265   People (Professional Employers Pvt Ltd) · Isla...
# 651   TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# 692   Fajar Real Estate · Lahore, Punjab, Pakistan (...
# ...

# %%
df_5=df_4.drop(df_4_uncomp_desc.index)
df_5
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 7266         Oracle Apps DBA - R12 (Full Customization)
# 7267                Engineer, Service-to-Service Fabric
# 7268  Technical Product Manager (OTE $80,000/year US...
# 7269                               Senior IOS Developer
# 7271  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
3542-66
# Out:
# 3476

# %% [markdown]
# #### using commen keywords used in IT and Tech

# %%
# it_tech_pattern='Software|Computer|Digital|Programming|Data|Freelance|Web|Cloud|Graphic|Game|Information technology|Mobile|Email|Virtual|video|technology|ecommerce|network'
# case=False
# filtered_df = df_5[df_5['Job Desception'].str.contains(it_tech_pattern, case)]
# filtered_df
it_tech_keywords= ['Software', 'Computer', 'Digital', 'Programming', 
                   'Data', 'Freelance', 'Web', 'Cloud', 'Graphic', 
                   'Game', 'Information technology', 'Mobile', 'Email', 
                   'Virtual', 'video', 'technology', 'ecommerce', 'network']
it_tech_keywords
len(it_tech_keywords)

filtered_df_5_desc = df_5[df_5['Job Desception'].apply(lambda desc: any(keyword.lower() in desc.lower() for keyword in it_tech_keywords))]
filtered_df_5_desc
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 7266         Oracle Apps DBA - R12 (Full Customization)
# 7267                Engineer, Service-to-Service Fabric
# 7268  Technical Product Manager (OTE $80,000/year US...
# 7269                               Senior IOS Developer
# 7271  Technical Product Manager (OTE $80,000/year US...
#
#                                                Job Info  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...
# 3     DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
filtered_df_5_desc['Job Title'].unique()
# Out:
# array(['LinkedIn Data Extractor', 'It Management Intern',
#        'SQL Database Developer', ...,
#        'Engineer, Service-to-Service Fabric',
#        'Technical Product Manager (OTE $80,000/year USD), Sparkrock',
#        'Senior IOS Developer'], dtype=object)

# %%
len(filtered_df_5_desc['Job Title'].unique()),len(df_3['Job Title'].unique())
# Out:
# (1912, 2343)

# %% [markdown]
# ### dealing Job titles where jobs desc is abnormal

# %%
len(df_3)-len(df_5) # there are 97 rows where Jobs desc= abnormal
# Out:
# 97

# %% [markdown]
# ##### approach:1

# %%
df_3.drop(df_5.index)
# Out:
#                                      Job Title  \
# 93    Digital Marketing Strategist and Planner
# 121                           Research Analyst
# 265              Software Engineer-Integration
# 651                            DevOps Engineer
# 692                    Real Estate Sales Agent
# ...                                        ...
# 6729                    React Native Developer
# 6733                           Finance Manager
# 6960                        IT Project Manager
# 6968                          Graphic Designer
# 7169             Talent Acquisition Specialist
#
#                                                Job Info  \
# 93    Prime Human Resource Services (Pvt) Ltd · Karā...
# 121   Indian School of Business · Hyderabad, Sindh, ...
# 265   People (Professional Employers Pvt Ltd) · Isla...
# 651   TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# 692   Fajar Real Estate · Lahore, Punjab, Pakistan (...
# ...

# %% [markdown]
# ##### Approach:2

# %%
# FUTURE TASK
# df_3[df_3['Job ID'].isin(df_4_uncomplete_desc_IDs+null_desc_iDS)]

# %% [markdown]
# #### getting df_3_abnormal

# %%
df_3_abnormal=df_3.drop(df_5.index)
df_3_abnormal
# Out:
#                                      Job Title  \
# 93    Digital Marketing Strategist and Planner
# 121                           Research Analyst
# 265              Software Engineer-Integration
# 651                            DevOps Engineer
# 692                    Real Estate Sales Agent
# ...                                        ...
# 6729                    React Native Developer
# 6733                           Finance Manager
# 6960                        IT Project Manager
# 6968                          Graphic Designer
# 7169             Talent Acquisition Specialist
#
#                                                Job Info  \
# 93    Prime Human Resource Services (Pvt) Ltd · Karā...
# 121   Indian School of Business · Hyderabad, Sindh, ...
# 265   People (Professional Employers Pvt Ltd) · Isla...
# 651   TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# 692   Fajar Real Estate · Lahore, Punjab, Pakistan (...
# ...

# %%
df_3_abnormal['Job Title']
# Out:
# 93      Digital Marketing Strategist and Planner
# 121                             Research Analyst
# 265                Software Engineer-Integration
# 651                              DevOps Engineer
# 692                      Real Estate Sales Agent
#                           ...
# 6729                      React Native Developer
# 6733                             Finance Manager
# 6960                          IT Project Manager
# 6968                            Graphic Designer
# 7169               Talent Acquisition Specialist
# Name: Job Title, Length: 97, dtype: object

# %%
df_3_abnormal['Job Title'].unique()
# Out:
# array(['Digital Marketing Strategist and Planner', 'Research Analyst',
#        'Software Engineer-Integration', 'DevOps Engineer',
#        'Real Estate Sales Agent', 'Software Quality Assurance Analyst',
#        'Google Ads Specialist', 'Android Developer',
#        'EY Ford Rhodes: Indirect & Direct Tax Compliance & Reporting Lead',
#        'Senior Asset Integrity Engineer',
#        'Senior .net core API developer', 'Senior MERN Stack Developer',
#        '2D Animators', 'Mechanical/Lifting Equipment Inspector',
#        'Unity  Android Mobile Game Developer', 'Junior iOS Developer',
#        'Executive Chef', 'Senior Angular Developer', 'QHSE Analyst',
#        'Digital Marketing Executive (Internship leading to permanent job)',
#        'Tax Intern', 'Business Development training program',
#        'Finance & Accounts Executive - R2R',
#        'Business Development Consultant',
#        'Associate, Customer Success (Sales)', 'Treasury Analyst',
# ...

# %% [raw]
# Tech keywords in df_3_abnormal:
#
# Digital
# software
# Analyst
# DevOps
# Google
# Android
# 2D
# Developer
# Development
# Graphic
# Game
# Search Engine Optimization
# Creative
# Video
# Virtual
# IT Sales
# Application
# Technical Content Writer
# IT Project
#
# some keywords where I have confusion:
#
#
# 'Senior Asset Integrity Engineer'
# 'Business Development training program'
# 'HARO Link Builder'
# 'Project Manager'
# 'CGI /Character Artist'
# 'Creative Marketing Specialist'
# 'Embedded System Engineer'
# 'Enterprise Resources Planning Developer'
# 'HR Site Lead (Jamshoro)'
# 'Senior Care Quality Assurance Associate'
# 'Bid Manager'
# 'Chief Technology Officer'
# 'B2B Account Executive (Sales)'
# 'Technical Associate Program 2023 - Excellent Opportunity for Fresh Graduates in Pakistan'

# %%
conf_titles=['Senior Asset Integrity Engineer','Business Development training program','HARO Link Builder',
             'Project Manager','CGI /Character Artist','Creative Marketing Specialist','Embedded System Engineer',
             'Enterprise Resources Planning Developer','HR Site Lead (Jamshoro)','Senior Care Quality Assurance Associate',
             'Bid Manager','Chief Technology Officer','B2B Account Executive (Sales)',
             'Technical Associate Program 2023 - Excellent Opportunity for Fresh Graduates in Pakistan']

# %%
# i am looking at Industry and company
df_3_abnormal[df_3_abnormal['Job Title'].isin(conf_titles)]
# Out:
#                                               Job Title  \
# 814                     Senior Asset Integrity Engineer
# 884               Business Development training program
# 1106                                  HARO Link Builder
# 1285                                    Project Manager
# 1288                              CGI /Character Artist
# 1914                      Creative Marketing Specialist
# 2044                           Embedded System Engineer
# 2061            Enterprise Resources Planning Developer
# 2271                            HR Site Lead (Jamshoro)
# 3182            Senior Care Quality Assurance Associate
# 3736                                        Bid Manager
# 5142                           Chief Technology Officer
# 5737                      B2B Account Executive (Sales)
# 6075  Technical Associate Program 2023 - Excellent O...
#
#                                                Job Info  \
# 814   Abyss Solutions Ltd · Islamabad, Islāmābād, Pa...
# ...

# %% [raw]
# IT keywords in conf_titles:
#
# Quality Assurance
# Project

# %% [markdown]
# #### developing IT tech pattern for Filtering job titles in df_3_abnormal:

# %%
# it_tech_pattern1='Digital|software|Analyst|DevOps|Google|Android|2D|Developer|Development|Graphic|Game'
# it_tech_pattern2='|Search Engine Optimization|Creative|Video|Virtual|IT Sales|Application|Technical Content Writer'
# it_tech_pattern3='|IT Project|Quality Assurance|Project'

# it_tech_pattern=it_tech_pattern1+it_tech_pattern2+it_tech_pattern3
# it_tech_pattern

# case=False
# filtered_df = df_3_abnormal[df_3_abnormal['Job Title'].str.contains(it_tech_pattern, case)]
# filtered_df
# len(filtered_df)

it_tech_pattern1 = ['Digital', 'software', 'Analyst', 'DevOps', 'Google', 'Android', '2D', 'Developer', 'Development', 'Graphic', 'Game']
it_tech_pattern2 = ['Search Engine Optimization', 'Creative', 'Video', 'Virtual', 'IT Sales', 'Application', 'Technical Content Writer']
it_tech_pattern3 = ['IT Project', 'Quality Assurance', 'Project']

it_tech_keywords = it_tech_pattern1 + it_tech_pattern2 + it_tech_pattern3
it_tech_keywords
len(it_tech_keywords)

# it_tech_keywords = ['Digital', 'software', 'Analyst', 'DevOps', 'Google', 'Android', '2D', 'Developer', 'Development', 'Graphic', 'Game',
#                     'Search Engine Optimization', 'Creative', 'Video', 'Virtual', 'IT Sales', 'Application', 'Technical Content Writer',
#                     'IT Project', 'Quality Assurance', 'Project']
# it_tech_keywords
# len(it_tech_keywords)

filtered_df = df_3_abnormal[df_3_abnormal['Job Title'].apply(lambda title: any(keyword.lower() in title.lower() for keyword in it_tech_keywords))]
filtered_df
len(filtered_df)
# Out:
# 57

# %% [markdown]
# #### Filtering Tech job titles in df_3_abnormal:

# %%
it_tech_keywords = ['Digital', 'software', 'Analyst', 'DevOps', 'Google', 'Android', '2D', 'Developer', 'Development', 'Graphic', 'Game',
                    'Search Engine Optimization', 'Creative', 'Video', 'Virtual', 'IT Sales', 'Application', 'Technical Content Writer',
                    'IT Project', 'Quality Assurance', 'Project']
it_tech_keywords
len(it_tech_keywords)

filtered_df_3_abnormal = df_3_abnormal[df_3_abnormal['Job Title'].apply(lambda title: any(keyword.lower() in title.lower() for keyword in it_tech_keywords))]
filtered_df_3_abnormal
# len(ffiltered_df_3_abnormal)
# Out:
#                                               Job Title  \
# 93             Digital Marketing Strategist and Planner
# 121                                    Research Analyst
# 265                       Software Engineer-Integration
# 651                                     DevOps Engineer
# 694                  Software Quality Assurance Analyst
# 699                               Google Ads Specialist
# 703                                   Android Developer
# 815                      Senior .net core API developer
# 816                         Senior MERN Stack Developer
# 819                                        2D Animators
# 821                Unity  Android Mobile Game Developer
# 822                                Junior iOS Developer
# 864                            Senior Angular Developer
# 880                                        QHSE Analyst
# 881   Digital Marketing Executive (Internship leadin...
# 884               Business Development training program
# ...

# %% [markdown]
# ### concatenating filtered_df_3_abnormal and filtered_df_5_desc:

# %%
filtered_df_3_Tech = pd.concat([filtered_df_5_desc,filtered_df_3_abnormal], ignore_index=True)
filtered_df_3_Tech
# Out:
#                                               Job Title  \
# 0                               LinkedIn Data Extractor
# 1                                  It Management Intern
# 2                                SQL Database Developer
# 3                       Business Intelligence Developer
# 4                            Web Developer - Internship
# ...                                                 ...
# 2892  Junior Market Analyst (Remote Internship – Mar...
# 2893                           Technical Content Writer
# 2894                             React Native Developer
# 2895                                 IT Project Manager
# 2896                                   Graphic Designer
#
#                                                Job Info   Job Type  \
# 0           EcomFleet · Pakistan (Remote)  \n1 week ago  Full-time
# 1     Digicon Valley · Lahore, Punjab, Pakistan (On-...  Full-time
# 2     Murkez Technologies · Lahore, Punjab, Pakistan...  Full-time
# ...

# %%
2840+57
# Out:
# 2897

# %% [markdown]
# ### getting non_tech_df3

# %%
# df_3.drop(filtered_df_3_Tech.index)
# # KeyError

# %%
non_tech_df3=df_3[~df_3['Job ID'].isin(filtered_df_3_Tech['Job ID'])]
non_tech_df3
# Out:
#                                               Job Title  \
# 5     Research Analyst for Business Subjects (Office...
# 6                          Performance Marketing Intern
# 94                 Search Engine Optimization Executive
# 96                            Machine Learning Engineer
# 106                             Human Resources Trainee
# ...                                                 ...
# 7244    Deputy Chief Engineer (Mechanical - Gas Engine)
# 7250                  Deputy Chief Manager (Compliance)
# 7254                                         Prosecutor
# 7258                                 Manager - Taxation
# 7262                  Chief Manager (Board Secretariat)
#
#                                                Job Info  \
# 5     TechoMatrix · Karāchi, Sindh, Pakistan (On-sit...
# 6     8th Loop · Karāchi, Sindh, Pakistan (On-site) ...
# 94    Brandix Soft  · Lahore, Punjab, Pakistan (On-s...
# 96    Mexa Solutions · Lahore, Punjab, Pakistan (On-...
# ...

# %%
2897+676
# Out:
# 3573

# %% [markdown]
# ### analyzing filtered_df_3_Tech['Job Title'] and non_tech_df3['Job Title']

# %%
len(filtered_df_3_Tech['Job Title'].unique()),len(df_3['Job Title'].unique()),len(non_tech_df3['Job Title'].unique())
# Out:
# (1946, 2343, 505)

# %% [markdown]
# ***why there are 505 unique job titles in non_tech_df3 it should be 397 so It may be unique titles in IT and non IT jobs(mixing)***

# %%
1946+505
# Out:
# 2451

# %%
len(df_3['Job Title'].unique())-len(filtered_df_3_Tech['Job Title'].unique())
# Out:
# 397

# %%
505-397
# 2451-2343
# Out:
# 108

# %% [markdown]
# ***108 job titles are mixed***

# %% [markdown]
# ### finding commen job titles

# %%
# l1=['A','B','C','D']
# l2=['A','B','C']
# l2 in l1
# type(l1)

# %%
commen_job_titles=np.intersect1d(filtered_df_3_Tech['Job Title'].unique(),non_tech_df3['Job Title'].unique())
# type(commen_job_titles)
commen_job_titles
# len(commen_job_titles)
# Out:
# array(['Account Assistant', 'Account Executive', 'Accountant',
#        'Admin Officer', 'Admissions Officer', 'Android Developer',
#        'Angular Developer', 'Animator', 'Appointment Setter',
#        'Assistant Manager', 'Assistant Manager Sales',
#        'Assistant Sales Manager', 'Associate', 'Bid Manager',
#        'Bid Specialist', 'Business Development Associate',
#        'Business Development Executive', 'Business Development Manager',
#        'Business Development Officer',
#        'Business Development Representative',
#        'Business Development Specialist', 'Call Center Representative',
#        'Career Counseling Specialist', 'Chief Technology Officer',
#        'Civil Engineer', 'Closer',
#        'Computer Numerical Control Programmer', 'Content Writer',
#        'Customer Sales Representative', 'Customer Service Officer',
#        'Customer Service Representative',
#        'Customer Support Representative', 'Digital Marketing Manager',
# ...

# %% [markdown]
# ***There are some Tech jobs in non_tech_df and non_tech_jobs in tech_df***

# %%
IT_titles_in_non_tech_df3=['Android Developer','Angular Developer','Animator','Bid Manager','Closer',
                           'Computer Numerical Control Programmer','Digital Marketing Manager',
                           'Digital Marketing Specialist','Flutter Developer','Machine Learning Engineer',
                           'Senior Web Developer','Shopify Developer','Social Media Manager','Sr. Angular Developer',
                           'Technical Content Writer','Technical Project Manager','UI/UX Designer','Upwork Bidder',
                           'Virtual Customer Experience Internship','Wordpress Developer','iOS Developer']
IT_titles_in_non_tech_df3
# Out:
# ['Android Developer',
#  'Angular Developer',
#  'Animator',
#  'Bid Manager',
#  'Closer',
#  'Computer Numerical Control Programmer',
#  'Digital Marketing Manager',
#  'Digital Marketing Specialist',
#  'Flutter Developer',
#  'Machine Learning Engineer',
#  'Senior Web Developer',
#  'Shopify Developer',
#  'Social Media Manager',
#  'Sr. Angular Developer',
#  'Technical Content Writer',
#  'Technical Project Manager',
#  'UI/UX Designer',
#  'Upwork Bidder',
#  'Virtual Customer Experience Internship',
#  'Wordpress Developer',
#  'iOS Developer']

# %%
filtered_df_3_Tech['Job Title'].unique()[:100]
# Out:
# array(['LinkedIn Data Extractor', 'It Management Intern',
#        'SQL Database Developer', 'Business Intelligence Developer',
#        'Web Developer - Internship', 'Sr. SDET Engineer',
#        'Associate Engineer', 'Fresh Graduate Engineers',
#        'Fraud Monitoring Officer', 'Business System Analyst',
#        'Research Analyst - Finance', 'HR Intern',
#        'Alfa Origin is looking for sales and HR Intern',
#        'Sales Operations Specialist', 'ASO Internee',
#        'Trainee R&D Engineer', 'Dotnet+React Developer',
#        'Business Development Executive (REMOTE) up to A$2,500/month',
#        'Artificial Intelligence Developer', 'Web Designer',
#        'Contact Centre Rep (REMOTE) up to A$ 2,000/month',
#        'Software Engineer', 'SQL Database Engineer',
#        'Junior Business Developer', 'Human Resources Intern',
#        'Antifraud Specialist', 'Management Trainee Officer',
#        'Jr Business Developer (Upwork)',
# ...

# %%
non_tech_df3['Job Title'].unique()[:100]
# Out:
# array(['Research Analyst for Business Subjects (Office Based + Night Shift)',
#        'Performance Marketing Intern',
#        'Search Engine Optimization Executive',
#        'Machine Learning Engineer', 'Human Resources Trainee',
#        'Business Development Executive',
#        'Fintech B2B Marketing Executive',
#        'Customer Support Representative', 'Ecommerce Manager',
#        'Territory Incharge [Future roles - Multiple Locations',
#        'Upwork Bidding Specialist', 'Upwork Bidder',
#        'Student Leader - Chemistry', 'Customer Service Representative',
#        'Business Development Specialist', 'Internal Auditor',
#        'Business Development Representative-Australia region',
#        'Marketing Executive', 'Business Development Representative',
#        'Human Resources and Admin Executive', 'Tax Officer',
#        'Sales Executive', 'Officer Sales Support - Sukkur',
#        'Study Abroad Advisor', 'Customer Sales Representative',
# ...

# %%
filtered_df_3_Tech['Job Title'].value_counts()[:50]
# Out:
# Job Title
# Business Development Executive                                              34
# Software Engineer                                                           28
# Educational Counselor                                                       26
# Sales Executive                                                             23
# Senior Software Engineer                                                    20
# Business Development Manager                                                16
# Graphic Designer                                                            16
# Dotnet Developer                                                            14
# DevOps Engineer                                                             13
# Full Stack Engineer                                                         13
# Wordpress Developer                                                         12
# Business Development Officer                                                12
# ...

# %% [markdown]
# ##### investigating Educational Counselor job

# %%
# filtered_df_3_Tech[filtered_df_3_Tech['Job Title']=='Educational Counselor'].iloc[0]['Job Desception']
# 'software' in filtered_df_3_Tech[filtered_df_3_Tech['Job Title']=='Educational Counselor'].iloc[0]['Job Desception']
# filtered_df_3_Tech[filtered_df_3_Tech['Job Title']=='Educational Counselor'].iloc[0]['Job Info']
# # These are some technical education related jobs

# %%
non_tech_df3['Job Title'].value_counts()[:50]
# Out:
# Job Title
# Sales Executive                                                     23
# Business Development Executive                                      13
# Sales Specialist                                                    11
# Salesperson                                                          9
# Business Development Manager                                         7
# Sales And Marketing Specialist                                       7
# Customer Service Representative                                      7
# Carrier Onboarding / Sales Executive at a Truck Dispatching LLC!     6
# Business Development Specialist                                      5
# Proofreader                                                          5
# Associate Project Sales                                              4
# Assistant Manager Sales                                              4
# Assistant Manager                                                    4
# ...

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
