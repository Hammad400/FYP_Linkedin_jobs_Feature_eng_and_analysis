# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### reading Feature Eng processed csv file

# %%
df=pd.read_csv('Feature Eng processed Files/Linkedin_Job_Details_and_Descriptions_26-Sep-2023-to-26-Nov-202311737-jobs_20-features_685-pages_Feature-Eng-processed_v5.csv')

# %% [markdown]
# ***This file have no duplicates and no missing values in Job details featues***

# %%
df
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df.shape
# Out:
# (11737, 20)

# %%
df.isnull().sum()
# Out:
# Job Title                0
# Job Info                 0
# Job Type                 0
# Job Link_x               0
# employees                0
# Job ID                   0
# Job Link_y               0
# Job Desception          31
# Company Info          2916
# company                  0
# location_1               0
# location_2               0
# Remote/Onsite            0
# n_applicant           4686
# job posting time         0
# Job Type nElements       0
# Job-Type                 0
# Experience Level         0
# Comp_N_Employees         0
# Comp_Industry            0
# dtype: int64

# %%
df_3=df.copy()

# %%
df_4=df_3.dropna(subset=['Job Desception'])
df_4
# Out:
#                                              Job Title  \
# 0                              LinkedIn Data Extractor
# 1                                 It Management Intern
# 2                               SQL Database Developer
# 3                      Business Intelligence Developer
# 4                           Web Developer - Internship
# ...                                                ...
# 11732                                  Unity Developer
# 11733  Manager – Growth Chat & SMS (Digital Marketing)
# 11734                  Information Security Specialist
# 11735        FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                              Community Associate
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# 3      DevNatives · Islamabad, Islāmābād, Pakistan (H...
# ...

# %%
df_4.shape
# Out:
# (11706, 20)

# %%
df_4_uncomplete_desc_IDs=[]
for i in range(0,len(df_4.iloc[:])):
    if len(df_4.iloc[i]['Job Desception'])<20:
        df_4_uncomplete_desc_IDs.append(df_4.iloc[i]['Job ID'])

# %%
df_4_uncomplete_desc_IDs
len(df_4_uncomplete_desc_IDs)
# Out:
# 1125

# %%
df_4_uncomp_desc=df_4[df_4['Job ID'].isin(df_4_uncomplete_desc_IDs)]
df_4_uncomp_desc
# Out:
#                                                Job Title  \
# 23              Digital Marketing Strategist and Planner
# 136                        Software Engineer-Integration
# 400                                      DevOps Engineer
# 433                              Real Estate Sales Agent
# 440                                Google Ads Specialist
# ...                                                  ...
# 11731  Senior Consultant- Business Consulting- Intern...
# 11732                                    Unity Developer
# 11734                    Information Security Specialist
# 11735          FUNCTIONAL CONSULTANT ORACLE FUSION - HCM
# 11736                                Community Associate
#
#                                                 Job Info  \
# 23     Prime Human Resource Services (Pvt) Ltd · Karā...
# 136    People (Professional Employers Pvt Ltd) · Isla...
# 400    TecBrix · Lahore, Punjab, Pakistan (Remote)  \...
# ...

# %%
df_5=df_4.drop(df_4_uncomp_desc.index)
df_5
# Out:
#                                                Job Title  \
# 0                                LinkedIn Data Extractor
# 1                                   It Management Intern
# 2                                 SQL Database Developer
# 3                        Business Intelligence Developer
# 4                             Web Developer - Internship
# ...                                                  ...
# 11727                 Technical Sales Support Specialist
# 11728                           YouTube Channel Producer
# 11729  Social Media Content Creator - Night Shift wit...
# 11730                                Design Sales agents
# 11733    Manager – Growth Chat & SMS (Digital Marketing)
#
#                                                 Job Info  \
# 0            EcomFleet · Pakistan (Remote)  \n1 week ago
# 1      Digicon Valley · Lahore, Punjab, Pakistan (On-...
# 2      Murkez Technologies · Lahore, Punjab, Pakistan...
# ...

# %% [markdown]
# #### using commen keywords used in IT and Tech

# %%
it_tech_pattern = 'game|Unreal|Unity'
it_tech_keywords=it_tech_pattern.split('|')
it_tech_keywords
len(it_tech_keywords)

filtered_df_3_title = df_3[df_3['Job Title'].apply(lambda title: any(keyword.lower() in title.lower() for keyword in it_tech_keywords))]
filtered_df_3_title
# Out:
#                                           Job Title  \
# 187                                     Game Tester
# 206                               Community Manager
# 395                    UX & Game Character Designer
# 425                             Community Counselor
# 431                                  Game Developer
# ...                                             ...
# 11385                               Unity Developer
# 11429                               Unity Developer
# 11533  Associate Officer, Community Program Support
# 11732                               Unity Developer
# 11736                           Community Associate
#
#                                                 Job Info  \
# 187    Khaleef Technologies · Lahore, Punjab, Pakista...
# 206    SIAR Digital · Karāchi, Sindh, Pakistan (On-si...
# 395    HR Ways - Hiring Tech Talent · Lahore, Punjab,...
# 425    Humraz Male Health Society Nawabshah · Nawabsh...
# ...

# %%
filtered_df_3_title['Job Title'].unique()
# Out:
# array(['Game Tester', 'Community Manager', 'UX & Game Character Designer',
#        'Community Counselor', 'Game Developer', 'Unity Developer',
#        'Unity  Android Mobile Game Developer', 'Game Planner',
#        'Game Marketer Manager',
#        'Senior Unity Developer, gt.school (Remote) - $100,000/year USD',
#        'Trainee Unreal engine developer', 'Game UI/UX Artist',
#        'Game Designer',
#        'Unity Game Developer, gt.school (Remote) - $100,000/year USD',
#        'Unity Developer, gt.school (Remote) - $100,000/year USD',
#        'Unreal Developer',
#        'Translation Project Task | Remote Work Opportunity - Korean and Chinese Speakers',
#        'Product Community Manager', 'Creative Unity Developer',
#        'Sr. Executive Community Management',
#        'Online Community & Outreach Executive',
#        'Junior Community Manager', 'Unity Game Developer',
#        'UNREAL DEVELOPER', 'Senior Community Management Associate',
# ...

# %%
len(filtered_df_3_title['Job Title'].unique())
# Out:
# 138

# %%
titles_to_drop=['Community Manager',
 'Community Counselor',
 'Translation Project Task | Remote Work Opportunity - Korean and Chinese Speakers',
 'Product Community Manager',
 'Sr. Executive Community Management',
 'Online Community & Outreach Executive',
 'Junior Community Manager',
 'Senior Community Management Associate',
 'Technical Associate Program 2023 - Excellent Opportunity for Fresh Graduates in Pakistan',
 'Community Associate',
 'Community Host',
 'Community Specialist',
 'WordPress Community Manager',
 'Kmart Warringah Mall- Team Member Opportunity',
 'Trainee Sales Executive (Outbound Sales & Marketing) - Entry-Level Opportunity',
 'WordPress Community Manager - HostWP.io',
 'Community Relations Manager',
 'Community Volunteer',
 'Community Mobilization Associate',
 "Join Elastic's Talent Community in APJ",
 'Articleship/ Training Opportunity',
 'Job Opportunity: Hiring Senior Python Backend Developer',
 'Community Investments Team Leader',
 'Senior Manager – Community Relations',
 'Community Mobilizer (CM)  (CDA  UC Rural-3 & 8)  Islamabad',
 'Community Mobilizer (CM)  (CDA  UC Rural-6 (Male - Pashtoon))  Islamabad',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 118)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 115)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 88)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 110)',
 'Community Mobilizer (CM)- Lahore (Aziz Bhatti Town UC 41)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 117)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 105)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 109)',
 'Community Mobilizer (CM)- Lahore (Aziz Bhatti Town UC 60)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 125)',
 'Community Mobilizer (CM)- Lahore (Aziz Bhatti Town UC 59)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 119)',
 'Community Communication Officer (District Level) - ICT',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 114)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 108)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 91)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 100)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 104)',
 'Community Mobilizer (CM)- Lahore (Aziz Bhatti Town UC 44)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 92)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 111)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 122)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-9)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 89)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 87)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-6)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-7)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 123)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-6)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-5)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 112)',
 'Community Communication Officer (District Level) - CDA',
 'Community Executive',
 'Community Mobilizer (CM) - Islamabad (ICT & CDA)',
 'Community Mobilizer (CM)- Lahore (Data Gunj Bakhsh Town UC 67)',
 'Community Mobilizer (CM)- Lahore (Data Gunj Bakhsh Town UC 73)',
 'Community Mobilizer (CM)- Lahore (Data Gunj Bakhsh Town UC 80)',
 'Community Mobilizer (CM)- Lahore (Data Gunj Bakhsh Town UC 72)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-99)',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 113)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-1)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 84)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-31)',
 'Community Mobilizer (CM)- Lahore (Aziz Bhatti Town UC 54)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 106)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-75)',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-37)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-32)',
 'Job Opportunity: .NET Expert at MERN IT Solutions in Islamabad!',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-51)',
 'Community Mobilizer (CM)- Lahore (Samanabad Town UC 103)',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-50)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-98)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-97)',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-53)',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-52)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-95)',
 'Community Mobilizer (CM)  (CDA  UC Mera Jaffar)  Islamabad',
 'Community Mobilizer (CM)- Lahore (Allama Iqbal Town UC 121)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-127)',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-96)',
 'Community Mobilizer (CM)  (CDA  UC Mera Badia)  Islamabad',
 'Community Mobilizer(CM) - Lahore (Gulberg Town UC-129)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-4)',
 'Community Mobilizer (CM) - Rawalpindi District',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-39)',
 'Community Mobilizer(CM) - Lahore (Cantt UC-W-5)',
 'Community Mobilizer(CM) - Lahore (Wagha Town UC-49)',
 'Community Mobilizer (CM)  (CDA  UC Rural-4 (Male - Pashtoon))  Islamabad',
 'Community Mobilizer (CM) - Lahore District',
 'Associate Officer, Community Program Support']
titles_to_drop
len(titles_to_drop)
# Out:
# 97

# %%
df_3_filtered=filtered_df_3_title[~filtered_df_3_title['Job Title'].isin(titles_to_drop)]
df_3_filtered
len(df_3_filtered)
# Out:
# 103

# %%
len(df_3_filtered['Job Title'].unique())
# Out:
# 41

# %%
it_tech_pattern_ = it_tech_pattern.replace('|', '-')
path=f"Filltered_Files/k-{it_tech_pattern_}_26_sep_to_26_nov_{len(df_3_filtered)}_jobs_{len(df_3_filtered['Job Title'].unique())}_titles_v5_Feature_Eng_Processed.csv"
path
# Out:
# 'Filltered_Files/k-game-Unreal-Unity_26_sep_to_26_nov_103_jobs_41_titles_v5_Feature_Eng_Processed.csv'

# %%
# df_3_filtered.to_csv(path,index=False)

# %% [raw]
# import pandas as pd
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# it_tech_pattern = 'IT|Tech'
# filtered_df = df[df['job_title'].str.contains(it_tech_pattern, case=False)]

# %% [raw]
# import pandas as pd
#
# it_tech_keywords = ['IT', 'Tech', 'Information Technology', 'Developer', 'Software Engineer', 'Data Scientist', ...]
#
# # Assuming your DataFrame is named 'df' and the job titles are in a column 'job_title'
# filtered_df = df[df['job_title'].apply(lambda title: any(keyword in title for keyword in it_tech_keywords))]
